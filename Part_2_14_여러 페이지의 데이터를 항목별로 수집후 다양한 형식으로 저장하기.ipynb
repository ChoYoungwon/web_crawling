# %%
# riss.kr 에서 특정 키워드로 논문 / 학술 자료 검색하기

#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time          

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까? : ')

#Step 3. 수집된 데이터를 저장할 파일 이름 입력받기 
ft_name = input('2.결과를 저장할 txt형식의 파일명을 쓰세요(예: c:\\py_temp\\riss.txt): ')
fc_name = input('3.결과를 저장할 csv형식의 파일명을 쓰세요(예: c:\\py_temp\\riss.csv): ')
fx_name = input('4.결과를 저장할 xls형식의 파일명을 쓰세요(예: c:\\py_temp\\riss.xls): ')

#Step 4. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://www.riss.kr/'
driver.get(url)
time.sleep(5)
driver.maximize_window()

#Step 5. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")

#Step 6.학위 논문 선택하기
driver.find_element(By.LINK_TEXT,'학위논문').click()
time.sleep(2)

#Step 7.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('div','srchResultListW').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n",""))

#Step 8. 총 검색 건수를 보여주고 수집할 건수 입력받기
import math
total_cnt = soup_1.find('div','searchBox pd').find('span','num').get_text()
print('검색하신 키워드 %s (으)로 총 %s 건의 학위논문이 검색되었습니다' %(query_txt,total_cnt))
collect_cnt = int(input('이 중에서 몇 건을 수집하시겠습니까?: '))
collect_page_cnt = math.ceil(collect_cnt / 10)
print('%s 건의 데이터를 수집하기 위해 %s 페이지의 게시물을 조회합니다.' %(collect_cnt,collect_page_cnt))
print('=' *80)

#Step 9. 각 항목별로 데이터를 추출하여 리스트에 저장하기
no2 = [ ]        #번호 저장
title2 = [ ]     #논문제목 저장
writer2 = [ ]    #논문저자 저장
org2 = [ ]       #소속기관 저장
no = 1

for a in range(1, collect_page_cnt + 1) :
    
    html_2 = driver.page_source
    soup_2 = BeautifulSoup(html_2, 'html.parser')

    content_2 = soup_2.find('div','srchResultListW').find_all('li')
    
    for b in content_2 :    
        #1. 논문제목 있을 경우만
        try :
            title = b.find('div','cont').find('p','title').get_text()
        except :
            continue
        else :
            f = open(ft_name, 'a' , encoding="UTF-8")
            print('1.번호:',no)
            no2.append(no)
            f.write('\n'+'1.번호:' + str(no))

            print('2.논문제목:',title)
            title2.append(title)
            f.write('\n' + '2.논문제목:' + title)
            
            writer = b.find('span','writer').get_text()
            print('3.저자:',writer)
            writer2.append(writer)
            f.write('\n' + '3.저자:' + writer)

            org = b.find('span','assigned').get_text()
            print('4.소속기관:' , org)
            org2.append(org)
            f.write('\n' + '4.소속기관:' + org + '\n')
            
            f.close( )
            
            no += 1
            print("\n")
            
            if no > collect_cnt :
                break

            time.sleep(1)        # 페이지 변경 전 1초 대기 

    a += 1 
    b = str(a)

    try :
        driver.find_element(By.LINK_TEXT ,'%s' %b).click() 
    except :
        driver.find_element(By.LINK_TEXT, '다음 페이지로').click()
        
print("요청하신 작업이 모두 완료되었습니다")

# Step 10. 수집된 데이터를 xls와 csv 형태로 저장하기
import pandas as pd 

df = pd.DataFrame()
df['번호']=no2
df['제목']=pd.Series(title2)
df['저자']=pd.Series(writer2)
df['소속(발행)기관']=pd.Series(org2)

# xls 형태로 저장하기
df.to_excel(fx_name,index=False, engine='openpyxl')

# csv 형태로 저장하기
df.to_csv(fc_name,index=False, encoding="utf-8-sig")

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
# Out:
# ====================================================================================================
#  이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.
# ====================================================================================================
# 1생태경관보전지역 내 철새도래지 서식환경 설계 연구 : 서울시 탄천 지역 사례 연구서지혜한양대학교2016국내석사RANK : 27772925원문보기음성듣기급속한 산업화와 도시화가 진행된 1960년대 이후 도시 생태계의 파괴, 기후변화, 도시 열섬현상 등 각종 도시환경문제를 초래하였다. 특히 도시지역에 있던 많은 자연생태계를 훼손시켰다. 그 중 도시 생태계에 서식하는 조류의 서식에 가장 큰 영향을 주었고 그 중 철새는 계절에 따라 번식지와 월동지 사이를 이동하는 중요한 새로, 개체 수가 감소했을 때 인위적인 회복이 어려워 철새 보호를 위한 국제적인 관심이 높다. 우리나라의 주요 철새도래지인 한강, 낙동강, 금강, 영산강 및 서해안을 대상으로 조류의 서식지 파괴 및 교란에 따라 조류의 수가 점차 감소되었고 많은 조류가 희귀종 또는 절멸위기종으로 파악되고 있다. 철새들에게 매우 중요한 중간기착지점인 우리나라는 삼면이 바다로 둘러싸여 있지만 도시화로 인해 철새도래지가 급격히 훼손되거나 사라지고 있는 실정이다. 이런 도시 내 철새도래지는 조류의 개체 수 증진 및 도시 내 생물종 다양성 증진에 있어 필수적인 사항이 되고 있다.이와 같은 문제점을 해결하고 도시지역에서도 자연생태계를 보전하기 위한 하나의 방안으로 생태경관보전지역을 설정하여 도시 단위에서 지정되어 운영되고 있다. 생태경관보전지역의 지정은 우리나라에서 도시화의 진행속도가 가장 빠르고 활발한 서울을 중심으로 시작되었다. 서울시의 17개 생태경관보전지역 중 한강 밤섬과 송파구 탄천은 도심속의 철새도래지로서의 역할을 하고 있다. 한강 밤섬은 안정적인 생태환경 유지를 위해 인간의 활동으로 인한 피해를 최소화하기 위해 출입을 제한하고 있다. 하지만 송파구 탄천은 생태경관보전지역으로 지정되었음에도 불구하고 제외지 또는 제방에 자전거 및 보행도로 개설, 지하철 및 교량 공사 등에 의한 인위적 간섭에 심하게 노출되어 개체 수가 줄어들고 있다. 따라서 본 연구는 탄천 주변부에 있는 도로, 교량 등 각종 도시 인프라의 간섭으로부터 철새도래지를 보호함과 동시에 탄천에 도래하는 조류에 대한 서식환경(생물상, 수환경, 물리적환경)요인을 고려한 서식모형을 제시하고 조류서식지와 주변환경을 통합한 서식지 디자인을 제시하고자 하였으며, 설계의 결과는 다음과 같다.첫째, 탄천 조류 서식환경 회복을 위해 서식환경을 고려한 조류서식모형을 제시하였다.둘째, 인간의 간섭을 최소화하기 위해 보행로를 최소화하고, 조류의 비간섭거리를 고려해 횃대, 인공섬, 징검다리, 식생완충대를 조성하였다.셋째, 조류관찰대와 환경생태교육 장소를 제공해 송파구 주민을 위한 생태 교육 환경을 조성하였다.  본 연구를 통하여 탄천 주변주에 있는 도로, 교량 등 각종 도시 인프라의 간섭으로부터 철새보호지를 보호함과 동시에 탄천에 도래하는 조류에 대한 서식환경 요인을 고려하여 안정적인 생태환경을 구축하고 생물다양성을 증진시키며 지역 주민을 위한 생태학습과 자연관찰 등 환경생태 교육장소가 될 수 있을 것으로 사료된다. 또한 본 연구는 탄천에 조류 서식환경 모형을 제시하고 탄천 조류서식지 복원 방안에 대한 설계안을 제시했다는 점에 의의가 있다. 나아가 지속적인 생물 서식환경 모니터링과 조류생태복원을 위한 연관분야(조경, 토목, 해양, 수리, 생물학)에 대한 정보와 후속연구가 이어져 통합적인 조류생태복원이 진행되어야 할 것이다.
# 원문보기
# 음성듣기
# 황(발)해 철새서식지 관광발전 현황과 해외 선진 사례에 대한 분석에 기초하여 세 가지 측면에서 황(발)해 철새서식지 생태관광을 활성화하기 위한 방안을 제시하였다. 첫째, 정부, 사회 및 대중이 세계자연유산을 지원하고 보호해야 한다. 유산 지역 보호와 옌청황해습지 생태관광을 추진하기 위한 정책 및 제도를 보완하고 선진과학기술을 활용하여 유산 지역 습지생태 관리를 지원함으로써 사람과 지역 관계의 조화로운 발전을 실현하여야 한다. 유산 지역에서는 인재 양성과 비축을 강화하고 관광지 공공서비스체계를 최적화하며 관광객의 관광 체험을 향상시켜야 한다. 둘째, 유산 지역의 생태관광 활성화는 관광상품 및 관광 프로그램의 혁신적 개발, 자연유산 관광브랜드 이미지의 형성과 시장 마케팅의 강화와 떼어놓고 생각할 수 없다. 셋째, 국립공원 조성, 유산 지역의 연계적 발전, 공동체 참여 및 생태교육 측면에서 해외 선진 사례의 습지생태관광에서의 성공적 발전 경험을 참고해야 한다.의 지속가능한 발전을 실현하는 데 도움이 된다.ds, adopt advanced science and technology to support the ecological management of the wetlands in the heritage sites, and realize the harmonious development of human-land relationship. Strengthen the training and reserve of talents in heritage sites, optimize the public service system of tourist sites, and enhance the tourist experience of tourists. Secondly, the activation of eco-tourism in heritage sites cannot be separated from the innovative development of tourism products and tourism projects, the shaping of the brand image of natural heritage tourism and the strengthening of marketing. Thirdly, we should learn from overseas advanced examples of activation programs in terms of national park construction, heritage site linkage development, community participation and ecological education. 습지는 ‘지구의 신장’으로 알려져 있으며 생태 안전과 경제 및 사회의 지속 가능한 발전을 보장하는 중요한 전략적 자원이다. 습지는 광활한 지리적 지역, 우수한 자연자원 및 생태환경으로 하여 중요한 관광 목적지로 되고 있다. 습지생태관광은 습지의 보호와 합리적인 이용, 지속가능한 발전을 실현하기 위한 최선의 관광방식이다. 본 논문의 연구 대상인 중국 황(발)해 철새서식지(제1기)는 2019년 7월 5일에 세계자연유산으로 등재되었는데 중국에서 처음으로 되는 해양과 직접 관련된 세계자연유산으로서 중국에서 생태보호가 육지에서 바다로 나아가는 첫 걸음을 뗀 것으로 된다. 황(발)해 철새서식지(제1기)는 장쑤성 옌청시에 위치하고 있어 옌청황해습지라고도 불리운다.
# 원문보기
# 목차검색조회
# 음성듣기
# 본 연구결과는 황하이 철새 보호지역이 지속 가능한 발전을 하기 위해 보존・관리 및 개발에 관한 객관적인 기초자료로 활용될 뿐만 아니라, 그 중요성에 대한 주민의 인식을 강화하는 데도 기여할 것이다.타났다. 로짓모형 분석결과를 토대로 1인당 연간 지불의사금액을 평가한 결과 절단된 평균값(WTP_truncated)을 기존으로 할 때 황하이 철새 보호지역 보존가치는 가설적 상황의 경우 259.07 위안(한화: 48,964 원), 실제상황1의 경우 210.87 위안(한화: 39,854 원), 실제상황2의 경우 135.42 위안(한화: 25,594 원)으로 평가되었다. 본 연구결과는 가설적 편의를 최소화할 뿐만 아니라, 진실한 가치를 산출하기 위해서는 실제상황을 토대로 보존가치를 추정하는 것이 필요하며, 보존가치의 과대평가를 최소화하기 위해서는 절단된 평균값이 바람직함을 제시해준다. 또한 본 연구결과 2021년 장쑤성 인구 수(62,242,383명)를 고려할 때 황하이 철새 보호지역 보존가치는 연간 약 84억 3천만 위안(한화: 약 1만 5 천 9 백억 원)으로 추정되었다.
# 원문보기
# 목차검색조회
# 음성듣기
# By analyzing the practice of the Winter Waterbird Census, this paper concludes that the migration of wild birds demonstrates deep non-human involvement in the South Korean biopolitical processes of both nature conservation and biosecurity safety alarms. This dissertation shows that migratory wild birds should be considered as having as a special relationship with human society as domesticated animals.tats for migratory birds, leading to the emergence of community-based conservation policy in the Biodiversity Management Contract. Recently, the Winter Waterbird Census has expanded to include an early-warning system which identifies any influx of avian influenza virus to the country with the migration of wild birds. The resources of the census program in the context of nature conservation have subsequently facilitated the visualization of virus movement by the Ministry of Agriculture and the adoption of protective biosecurity measures. As a result of conducting the census, migratory birds are involved not only in issues of conservation but also in keeping the human population and agricultural animals safe from viral threats. cess in South Korea.irds from population size and numbers of species, the South Korean government has used it as an indicator for where nature requires conservation and a warning sign to take biosecurity measures when the lives of humans and farm animals are threatened.
# 원문보기
# 목차검색조회
# 5韓國에 渡來하는 철새의 生態와 保護管理 : 특히 西海岸에 渡來하는 水鳥類에 대하여金鎭漢慶熙大學校 大學院1998국내석사RANK : 27772863복사/대출신청
# 복사/대출신청
# 6제주도 텃새와 철새에서 조류 말라리아의 조사Rachynska Kateryna제주대학교 대학원2023국내석사RANK : 27772829복사/대출신청
# 복사/대출신청
 철새에 의해 지속적으로 전파되고 있다. 본 연구는  2006년과 2011년도에 국내 야생 철새의 분변에서 분리한 고병원성 인플루엔자 H5N1 바이러스(A/EM/Korea/W401/11 와 A/EM/Korea/W404/11)의 잠재적 병원성규명을 하고자 하였다.  두 바이러스의 전체 8개의 유전자분석 연구결과, 2011년에 분리된 HPAI H5N1 바이러스는 2006년에 분리된 바이러스와는 계통학적으로 다른 것으로 나타났으며, 오히려 최근 일본에서 분리된 A/Whooper swan/Hokaido/4/11과 유사하였으며, 2.3.2 clad에 속하는 몽골계 바이러스군에 속하는 것으로 밝혀졌다(유사도 : 99.8%). 두 바이러스 모두 HA 유전자에 multi-basic cleavage site (QRERRRK/R)를 갖고 있지만, 다른 내부 유전자에서는 추가적으로 병원성 특성을 나태는 virulence marker는 발견되지 않았다. 2011년데 분리된 HPAI H5N1바이러스의 잠재적 병원성을 비교하기 위하여 2006년 국내 야생 철새에서 분리된 2.2 clade의  H5N1 바이러스 (A/EM/Korea/W149/06)를 비교군으로 하여, 닭, 쥐, 족제비에서 병원성 비교 실험을 수행 하였다.  숙주별 비교 감염 실험에서 두 바이러스 모두 닭(2.3-3.0 LD50)과 쥐(3.3-3.9 LD50)등과 같이 고병원성의 특징을 나태내었지만, A/EM/Korea/W401/11 바이러스는 오리와 흰족제비 실험에서는 A/EM/Korea/W149/06에 비하여, 비교적 낮은 병원성을 보였다. 특히, 두 바이러스 모두 감염된 페렛의 상부 호흡기에 감염되어 증식하였지만, 감염된 페렛에서 간접접촉 페렛으로의 전파는 일어나지 않았다.  이러한 결과는 국내에서 분리된 HPAI H5N1 바이러스들은 포유동물에도 효과적으로 감염되어 증식할 수 있는 능력을 가졌지만, 페렛과 같은 포유류에서 연속적인 감염을 지속시키지는 못한다는 것을 의미한다.  본 연구 결과는 동아시아 지역에서의 고병원성 H5N1 바이러스의 감염과 전파에 야생철새의 중요성을 규명하였으며, 또한 지속적인 야생 철새에서의 고병원성 인플루엔자 바이러스의 분리 및 역학조사의 중요성을 보여주고 있다.
# 원문보기
# 음성듣기
# 10서낙동강 일원 환경중의 POPs 축적레벨과 철새도래지 보호·관리방안에 관한 연구洪喜均慶南大學校 敎育大學院2005국내석사RANK : 27772795원문보기목차검색조회음성듣기In this work, author investigated the role of the West Nakdong river as an influx of a migratory birds by examining the chlorinate organic compounds remained in this area, and also measured the accumulative level of the chlorinate organic compounds in this area , which can be used for building appropriate maintenance strategy.Although the area of west Nakdong river is famous for its beautiful scene as an influx of migratory birds and supplies water to farms in Kimhea, it was reported that there were lots of harmful POPs including PCBs and DDTs. POPs are not allowed to be imported or used in Korea since 1970 but the chlorinate organic compounds were detected from the surface sediments as well as small animals including shells, fishes, insects and small mammals. Especially, DDTs and HCHs are increasing as time goes while PCBs are reducing; this zone is affected by pollutants from the farm of this area.Since the PCB, DDTs and HCHs are accumulated in creatures through food chain, which is called, it is strongly recommended to concentrate our efforts for antipollution in this area. Therefore, author proposes to establish long-term strategies for environmental preservation in this area such as tightened environmental standard, the increased number of equipments for pollution prevention and strict monitoring and report for pollutants. 서낙동강 일원의 유기염소계화합물 잔류현황 및 분포특성을 파악하여 본 지역의 철새도래지로서의 역할을 재조명하며, 적절한 보호·관리방안을 수립하기 위하여 서낙동강 일원 환경중의 유기염소계화합물 축적레벨을 파악하였다.서낙동강 일원은 철새도래지로서 평상시에는 광활한 김해평야의 주요 농업용수 공급원으로 사용되고 철새들의 도래지로 아름다운 하천경관을 자랑하고 있지만, PCBs 및 DDTs와 같은 유기염소계화합물이 전 지역에 걸쳐 폭넓게 잔류하고 있음이 밝혀졌다. 1970년대 이후 유기염소계화합물이 수입, 사용금지되었음에도 불구하고 서낙동강 일원 표층퇴적물, 어·패류, 소형포유류 및 곤충류에서 유기염소계화합물이 전 조사지역에서 검출되었고, 특히 PCBs는 기존조사에 비하여 감소하는 경향을 보였으나 유기염소계농약인 DDTs 및 HCHs는 높은 농도로 검출되어 주변지역에서 배출되는 오염물질의 영향을 받고 있는 것으로 나타났다. 또한 PCBs, DDTs 및 HCHs 등과 같은 유기염소계화합물은 생물체에 미량으로 축적되어 food chain을 통한 생물농축현상에 의하여 고등동물의 생체 내에 축적되는 화학물질이므로, 향후 철새들의 서식지인 서낙동강 일원의 유기염소화합물에 대한 오염현황의 파악 및 오염원의 확인 및 지속적인 오염 억제 노력이 요구된다. 또한 철새들을 보호하고 서낙동강 일원의 생태계 보존 및 관리를 위하여 환경기준의 강화, 환경오염방지시설의 확충, 점오염원에 대한 모니터링 등, 장기적인 대책이 수립되어야할 것이다.
# 원문보기
# 목차검색조회
# 음성듣기
# 검색하신 키워드 철새 (으)로 총 295 건의 학위논문이 검색되었습니다
# 22 건의 데이터를 수집하기 위해 3 페이지의 게시물을 조회합니다.
# ================================================================================
# 1.번호: 1
# 2.논문제목: 생태경관보전지역 내 철새도래지 서식환경 설계 연구 : 서울시 탄천 지역 사례 연구
# 3.저자: 서지혜
# 4.소속기관: 한양대학교
#
#
# 1.번호: 2
# 2.논문제목: 중국 황(발)해 철새서식지의 관광지 활성화에 관한 연구
# 3.저자: 오염위
# 4.소속기관: 우석대학교 일반대학원
#
#
# 1.번호: 3
# 2.논문제목: CVM을 이용한 세계자연유산  황하이 연안-보하이 만 철새 보호지역의 보존 가치 평가
# 3.저자: WU SHIYAO
# 4.소속기관: 경희대학교 대학원
#
#
# 1.번호: 4
# 2.논문제목: 자연의 지표(指標)에서  생명의 경보(警報)로 : 철새 센서스와 인간 너머의 생명정치
# 3.저자: 성한아
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 5
# 2.논문제목: 韓國에 渡來하는 철새의 生態와 保護管理 : 특히 西海岸에 渡來하는 水鳥類에 대하여
# 3.저자: 金鎭漢
# 4.소속기관: 慶熙大學校 大學院
#
#
# 1.번호: 6
# 2.논문제목: 제주도 텃새와 철새에서 조류 말라리아의 조사
# 3.저자: Rachynska Kateryna
# 4.소속기관: 제주대학교 대학원
#
#
# 1.번호: 7
# 2.논문제목: 제주도내 철새 탐조활동을 위한 물새류에 관한 연구
# 3.저자: 송승헌
# 4.소속기관: 濟州大學校 敎育大學院
#
#
# 1.번호: 8
# 2.논문제목: 을숙도의 철새로부터 분리된 조류인플루엔자 바이러스의 유전적 특성 : Genetic Characterization of Avian Influenza Viruses Isolated from Waterfowl in Eulsukdo
# 3.저자: 오정훈
# 4.소속기관: 충남대학교 대학원
#
#
# 1.번호: 9
# 2.논문제목: 2011년 국내 철새에서 분리한 고병원성 조류 인플루엔자 H5N1 바이러스의 병원성과 유전적 특징
# 3.저자: 권혁일
# 4.소속기관: 충북대학교
#
#
# 1.번호: 10
# 2.논문제목: 서낙동강 일원 환경중의 POPs 축적레벨과 철새도래지 보호·관리방안에 관한 연구
# 3.저자: 洪喜均
# 4.소속기관: 慶南大學校 敎育大學院
#
#
# 1.번호: 11
# 2.논문제목: Surveillance and genetic evolution of H5 avian influenza viruses from migratory birds in South Korea during 2014-2017
# 3.저자: Hiep Dinh Nguyen
# 4.소속기관: 충북대학교
#
#
# 1.번호: 12
# 2.논문제목: 대체 현실 게임 스토리텔링의 현존하는 캐릭터를 활용한 인터랙티브 아트 연구 : 본인 작품 < 철새들의 집 >을 중심으로
# 3.저자: 김민지
# 4.소속기관: 이화여자대학교 대학원
#
#
# 1.번호: 13
# 2.논문제목: Analysis of virome in ticks collected from rescued wild animals and captured migratory birds in the Republic of Korea
# 3.저자: 류미선
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 14
# 2.논문제목: 철새의 정위기제에 관한 핵자기공명 모형
# 3.저자: 김원근
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 15
# 2.논문제목: 철새 중간기착지에서 발생하는 조류사고원인 분석에 관한 연구
# 3.저자: 빙기창
# 4.소속기관: 조선대학교 대학원
#
#
# 1.번호: 16
# 2.논문제목: 영종하늘도시 철새공원 조성계획
# 3.저자: 고우용
# 4.소속기관: 서울대학교 환경대학원
#
#
# 1.번호: 17
# 2.논문제목: 국내 철새에서 분리한 저병원성 H7 조류 인플루엔자 바이러스의 감시 조사 및 특성분석
# 3.저자: 김영일
# 4.소속기관: 충북대학교
#
#
# 1.번호: 18
# 2.논문제목: 洛東江河口 철새集團의 群集生態에 關한 硏究
# 3.저자: 이정일 (李正一)
# 4.소속기관: 東國大學校 大學院
#
#
# 1.번호: 19
# 2.논문제목: 국내 철새에서 분리한 저병원성 H5 조류 인플루엔자 바이러스의 감시 조사 및 특성분석
# 3.저자: 백윤희
# 4.소속기관: 충북대학교
#
#
# 1.번호: 20
# 2.논문제목: 鏡浦湖의 철새 集團硏究
# 3.저자: 진경일
# 4.소속기관: 江原大學校
#
#
# 1.번호: 21
# 2.논문제목: 乙淑島와 注南貯水地 철새集團의 生態學的인 硏究
# 3.저자: 백운기
# 4.소속기관: 慶南大學校
#
#
# 1.번호: 22
# 2.논문제목: 을숙도와 주남저수지 철새의 생태학적인 연구
# 3.저자: 백운기
# 4.소속기관: 경남대학교
#
#
# 요청하신 작업이 모두 완료되었습니다
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
