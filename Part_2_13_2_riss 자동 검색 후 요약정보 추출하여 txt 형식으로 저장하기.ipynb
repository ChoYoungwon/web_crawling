# %%
#Chap 13. riss.kr 사이트에서 특정 키워드로 자동 검색하기

#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time          

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 해양자원): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://www.riss.kr/'
driver.get(url)
time.sleep(5)
driver.maximize_window()

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")

#Step 5.학위 논문 선택하기
driver.find_element(By.LINK_TEXT,'학위논문').click()
time.sleep(2)

#Step 6.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('div','srchResultListW').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

#Step 7. 표준 출력 방향을 바꾸어 txt 파일에 저장하기
import sys 
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\riss.txt): ')

orig_stdout = sys.stdout
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file  #모니터에 출력하지 말고 file 에 출력해라

for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()    
sys.stdout = orig_stdout  #원래대로 변경 - 다시 화면에 출력시켜라    

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)
# Out:
# ====================================================================================================
#  이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.
# ====================================================================================================
#
#
# 1   한강 위에 세워지는 문화가로 계획안  최순용 建國大學校 建築大學院 2002 국내석사  RANK : 27772927    원문보기             서울이라는 도시는 600년이나 된 역사도시(歷史都市)로써 기본적으로 사대문성안의 구도시(舊都市)와 근대화와 더불어 한강을 포함하는 신도시(新都市)로 확장되어갔다. 서울의 경계가 외곽으로 확장되어 가면서 한강은 지리적으로 서울의 중심위치에 놓이게 되었다. 한강은 서울을 상징하는 거대한 자연공간이면서, 도시의 거대한 공공공간으로서의 기능과 가능성을 충분히 가지고 있다. 그러므로 오늘날 대도시 서울에서 한강이 갖는 위상(位相)은 보다 중요해졌다. 그러나 지금의 서울은 외곽으로 확장만을 추구하는 도시계획으로 인해 도시의 비대화(肥大化)과 도시공동화(部市空洞化)현상과 같은 도시문제를 낳고 있다. 그 중심에 선 한강은 거대한 스케일(Scale)로 인해 두 도심의 가장자리(urban edge)로 인식되어 강남북을 단절시키고, 강남과 강북의 주요 시설물과 연계되지 못하고 있다. 이러한 도시의 이중성으로 인해 하나의 도시가 강북과 강남으로 이분되어 문화의 교류와 행해가 다르게 나타난다는 것은 생각해 볼 문제이다. 또한 강남북으로 건설된 제방도로(강북도로, 올림픽대로)로 인해 한강고수부지로의 접근이 어려우며, 수변공간이 단조롭고, 휴식과 운동 등의 단순화된 기능위주로 수변공간의 활용이 다양하지 못한 실정이다. 아울러 강변에 볼거리와 랜드마크(landmark)가 거의 없는 현실에서 한강을 새롭게 열린 도시공간으로의 인식의 전환이 필요하다. 다시 말해서, 도심 속의 강이 줄 수 있는 혜택을 제대로 활용하지 못하고 있는 것이다. 이 계획의 목적은 대도시 서울의 중심성을 회복하여 외곽으로만 확장되어 가는 서울 도시발전에 내실을 도모하며, 거대한 한강의 스케일을 극복하며, 강북과 강남의 문화가 만날 수 있는 장소로서 한강이라는 경계를 설정하여 한강이 서울 도시민의 공공의 장(場)으로 거듭나도록 하기 위한 살아있는 다리(Living Bridge)를 계획하기 위함이다. 본 계획은 88년 서울올림픽이후 도시의 대규모공중 공간으로 제대로 활용되지 못하고 있는 잠실주경기장과 최근 지하철 7호선 뚝섬유원지역의 개통으로 강북의 새로운 문화공간으로 자리 잡아가는 뚝섬유원지를 연계하는 문화가로를 한강 위에 계획하고자 한다. 이를 위해 본 계획안은 첫째, 다리(Bridge)에 도시프로그램(Urban program)을 설정하여 한강을 이용하거나 주변의 사는 도시민의 문화적 욕구를 충족시킬 수 있도록 하여 도심 속에 새로운 공원으로 거듭나고자 한다. 둘째, 강남북 접근로의 지형적 특성에 대응하여 각기 다른 레벨(Level)의 3개의 판(Plate)를 설정하여 사람들로 하여금 쉽게 접근할 수 있도록 한다. 셋째, 잠실주경기장의 비활용적 상황을 고수부지와 다리의 프로그램과 연계시킴으로써 도심의 공공장소(A grand public urban space)로써 재탄생 시킬 것이다. 넷째, 이 다리는 한강의 새로운 랜드마크(urban-landmark)로써 서울시민들의 한강에 대한 인식을 새롭게 할 것이다. 이상과 같이 본 계획안은 한강 위에 세워지는 문화가로로써 한강변의 이용자뿐만 아니라 주변 도시민들의 새로운 문화공간으로 자리잡아 도시생활에 새로운 명소가 될 것이다.
#
#
# 원문보기
#
#
# 2   한강 소설의 인물 정체성 연구 : 인물 정체성과 갱신의 양상을 중심으로  정서화 연세대학교 교육대학원 2012 국내석사  RANK : 27772927    원문보기 음성듣기             본 연구의 목적은 한강 소설에서 형상화되고 있는 인물들에서 주로 부각되는 인물 정체성을 분석하고 그 갱신의 양상이 어떤 식으로 나타나는지를 규명하는 데에 있다. 인물의 내면을 형상화하고 드러나지 않는 것들에 관심을 가지는 한강 소설 연구에 있어서 인물에 대한 연구는 소설을 이해하는 주요한 통로가 되어줄 수 있을 것이다.    그간 한강 소설에 대한 연구는 주로『채식주의자』연작에 집중되는 경향이 있었다. 그러나 지금까지 5권의 장편 소설을 펴낸 작가의 작품을 연속적으로 이해하려는 시도를 하는 연구는 많지 않았다. 한강의 장편 소설의 경우 최근의『희랍어 시간』에서 보이는 일련의 변화를 고려할 필요가 있다. 지금까지의 인물들의 주요한 인식 통로로 활용되던 시각과 언어를 두 주인공이 잃게 되는 상황은 이전까지의 작품들에 대한 어떤 연속적인 이해가 필요함을 촉구한다.     단편 소설의 경우 초기의 작품들에서 방랑자의 모습으로 나타나는 경향을 보이는 인물들의 탈주는 그들 자신의 고향과 집을 등지도록 만든다. 그러나 떠난 후에도 그들을 유령처럼 따라다니는 과거의 잔해들은 그들로 하여금 안식과 목적지 모두를 잃게 만든다. 때문에 한강의 초기 작품들에서 인물들은 피로한 얼굴로 정처 없이 방황하고 있다. 더불어 이들 인물들의 방향은 도시로의 여정과도 상통하는데 이 도시인으로서의 생활은 인물들의 삶에 어떤 대안이 되어주지 못하고 있다. 결국 이들이 스스로의 내면의 기억과 싸우고, 도시에서의 강퍅한 삶을 견디는 동안 어떤 병의 징후들이 나타나게 된다.    한강의 여성 인물들에서 주로 나타나는 각종 질병들은 육체적인 것에서부터 정신적인 것에 이르기까지 다양하게 나타나는데 근작으로 올수록 심인성 질환의 성격이 강해지고 있다. 이러한 여성 인물들은 대체로 육체적으로도 연약하고 마른 특징을 보이는데, 이들 여성 인물들의 이러한 특성들을 설명할 수 있는 모델로 팜므 프라질Femme Fragile을 들 수 있다. 본래 19세기 낭만주의 문학에서 유래된 이 여성 모델은 아이와 같은 외모와 연약하고 창백한 아름다움을 지닌 이상적 여성상으로 팜므 파탈Femme Fatale과 대비되는 성격을 지니고 있었다. 한강 소설에 나타나는 여성 인물들은 이러한 여성 모델과 외향적으로 공통된 특징을 보이면서도 병적인 징후가 강화되는 형태로 형상화되고 있으며, 다른 한편으로 현대적인 팜므 프라질Femme Fragile의 특징인 자기 소멸에의 의지를 강하게 드러내기도 한다.    현실에서의 고통과 싸우는 인물들의 의지는 소수의 인물들에 있어서는 종교적인 초월의 형태로 나타나기도 하지만 한강의 장편에서 주로 드러나고 있듯이 창작 활동에 몰두하는 형태로 나아가기도 한다. 한강의 장편 소설에서 거의 모든 주요 인물은 예술가로 설정되어 있다. 한강의 소설에서 인물들이 예술가적 정체성을 지닌다는 것은 이들의 직업이라는 표면적인 조건에서 그치는 것이 아니라는 점에서 더욱 중요하다. 이들의 창작품은 소설 속에서 비중 있게 다루어지고 있으며 이들이 자신의 창작 세계에서의 갱신을 이루는 것은 인물들의 삶과 관계에 있어서의 변화와도 궤를 같이하고 있다. 이 작품들은 주로 구상에서 비구상적인 형태로의 이행을 보이고 있으며, 이는 대상의 숨겨진 본질을 탐구함으로써 그 대상을 더욱 사실적으로 드러낼 수 있다는 추상적인 예술 기법과 연관된다. 나아가 이러한 허구 속의 허구의 변화 과정은 기존의 고전적인 문학 스타일에서 벗어나 말해질 수 없는 것들에 대해 쓰고자 하는 작가 자신의 문학적 개성을 확립하는 과정과도 맞물리고 있다. 예술가로서 제작에 참여하여 스스로의 삶과 자신을 둘러싼 관계의 변화를 경험하는 인물들이 있다면 종교적 초월로도, 제작자로도 나아가지 못하고 현실에서 힘겨운 고투를 이어가는 것으로 갱신을 이루는 인물들 또한 존재한다.      한강의 초기와 근작의 단편들에서 꾸준히 드러나는 것은 노동에 대한 관심이다. 가난이나 일상의 유지를 위해서 육체적으로 혹은 정신적으로 고단한 노동을 해나가는 인물들의 이야기는 초기의 청년들에서 근작의 장년들로 이어진다. 초기의 청년들이 가난과 싸우는 형태였다면 근작의 노동은 일상의 반복에 따른 피로와 대면하고 있다. 이러한 노동하는 삶은 초기의 방랑하는 인물들이 도시로 오게 되면서 드러내는 일종의 정주에의 의지로 볼 수 있다. 이들의 노동이 삶의 지속을 위한 외적 자세라면, 그 내적 자세는 견딤의 미학으로 드러난다. 초기 단편들에서 그 내면적 싸움이 병이나 주먹 쥔 손 등으로 표현되었다면, 근작의 단편들에서는 의식의 흐름 기법을 활용하여 그 내적 고투를 더욱 효과적으로 드러내고 있다. 근작에 이르러 이러한 내적 싸움은 그 자신의 고통을 숭고함의 경지로까지 끌어올리는 단계에 이르고 있다.    한강의 소설에서 나타나는 인물들의 정체성과 그 갱신의 양상들은 인간이 자신의 상처와 고통을 직시하고 자기 소멸의 위험을 무릅쓰면서 나아가고자 하는 자기 갱신의 의미와 그로부터 역설적으로 지속되는 삶의 의미에 대해 생각하게 한다.
#
#
# 원문보기
#
#
# 음성듣기
#
#
# 3   한강 조망권과 일조권이 아파트 가격에 미치는 영향  김희창 건국대학교 부동산대학원 2015 국내석사  RANK : 27772927    원문보기 목차검색조회 음성듣기             서울은 한강이 그 중심부를 동측에서 서측으로 흐르고 있고, 주요 자연경관인 남산, 아차산, 북한산과 등과 어우러져 매우 아름다운 도시이다. 올림픽도로와 강북도로에서 차량을 운행하면서 시원스럽게 탁 트인 한강을 바라볼 수 있다. 한편 한강 주변은 대부분이 획일적인 한일자 판상형 구조의 아파트단지로 구성되어 있고, 병풍식 아파트 외관으로 인하여 시선이 차단되어 있어 도시미관을 해치고 있다. 한강 주변에서 한강의 수려한 경관과 조화를 이루고 있고 620년 역사의 수도에 걸맞는 고색창연한 건축물이나 현대적으로 신축된 아름다운 건축물 하나 마주할 수 없는 아쉬움이 크다.     한강 북측주변의 아파트에서는 한강을 조망할 수 있는 반면 한강 남측주변에서는 일조를 중시하여 남향의 아파트 단지로 구성되어 있어 한강을 조망할 수 없는 현실이다. 소득수준의 향상에 따라 한강을 조망할 수 있는 아파트가 그렇지 못한 아파트보다 높은 가격으로 거래되고 있다.     한강 조망권 또는 일조권이 주택가격에 미치는 영향에 대하여 수인의 선행연구에서 분석되었다. 그러나 한강 조망권과 일조권이 아파트가격에 미치는 영향의 크기를 동시에 비교 분석하여 연구한 사례는 없었다.     이 연구는 한강 조망권과 일조권이 아파트가격에 미치는 영향의 크기를 동시에 비교 분석하여 한강 남측주변에서 한강을 조망할 수 있도록 아파트의 북향 배치에 관하여 연구하였다. 분석방법으로는 아파트 가격의 구성요소를 특성감안가격모형으로 하여 회귀분석을 실시하였다. 가격자료는 2014년 8월 31일 기준으로 한강 조망여부가 갈리는 한강 북측주변에서 한강에 면한 아파트와 후면 아파트의 로열층 최고가격을, 일조 양호 여부가 갈리는 후면동의 로열층의 최고가격과 1층 또는 최저층 중간가구의 최저가격 등 25개 아파트단지의 34개 평형 138개 아파트의 가격을 현지 조사하여 평가한 가격으로 분석하였다.     변수 구성에서 종속변수는 평당가격을, 독립변수는 아파트 가격 구성요소를 단지특성, 건물특성, 환경특성으로 분류하고 이와 관련된 세부적인 가격특성을 조사하여 24개 특성감안가격변수를 설정하였다.    종속변수인 평당가격을 로그 변환하여 회귀분석한 결과 표준화 베타계수는 한강조망의 영향이 0.217로 일조의 영향 0.102와 남향의 영향 0.101의 합계 0.203 에 비하여 6.9%상당 높아 한강 조망권의 영향력이 일조권과 남향의 영향력을 능가하는 것으로 분석되었다. 이는 한강 남측주변의 아파트 재건축시 북향 배치가 바람직함을 시사한다. 수정결정계수(Adjusted R)는 0.913으로 설명력이 높았고, F값은 97.373, 유의확률은 전체적으로 1%수준에서 유의하였으며, 변수별로는 한강조망은 1%수준에서 일조와 남향은 5%수준에서 유의하였다.    아파트의 북향 배치는 가족들의 주된 생활공간인 거실을 북향으로 배치하는 것이다. 아파트를 북향으로 배치하였을 경우 일조량이 부족할 우려가 있으나 한강변의 아파트는 고가이고 면적이 큰 관계로 방1-2개는 남향으로 배치할 수 있어 일조량은 부족하지 않다. 또한 한강의 흐름에 따라 단지계획을 수립하면 정북방향은 피할 수 있다.    한강 남측주변은 잠실, 신천동 일부, 암사동 일부를 제외하고 대부분이 향후 아파트 재건축이 예정되어 있어 아파트 북향 배치는 물론 획일적인 판상형 구조에서 탈피하여 새로운 아파트 모형(외관)을 개발하고 단지계획수립에서 일반인이 자유롭게 드나들 수 있는 상가, 주민공동시설 등을 도로변이 아닌 한강주변에 배치하여 서울의 주된 자연경관인 한강이 남산, 아차산, 인왕산, 북한산, 낮은 자연구릉지 등과 어우러져 조화를 이루게 하여 수려한 경관의 서울의 도시이미지를 향상시키는 변화 또는 정책이 요망된다.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 4   韓江小說의 中譯本《素食主義者》의 번역양상 연구  주몽희 숭실대학교 대학원 2019 국내석사  RANK : 27772927    복사/대출신청
#
#
# 복사/대출신청
#
#
# 5   한강공원특화사업 프로그램의 이용후 평가 연구 : 여의도 권역과 반포 권역을 대상으로  정다현 한양대학교 도시대학원 2013 국내석사  RANK : 27772927    원문보기 목차검색조회 음성듣기             한강공원특화사업은 한강의 이용 활성화를 위해 한강공원 중 4개 권역(여의도, 난지, 뚝섬, 반포)을 대상으로 각각의 테마를 가진 특화공원 조성을 목표로 한 사업이다. 이 4개 권역은 한강공원의 총 12개 권역 중 이용률 상위 5위안에 들고 있으나, 사업이 완료된 후 3년이 지났음에도 불구하고 이용 효용성에 대한 평가는 이루어지지 않고 있는 상황이다.  이에 본 연구는 이용의 관점에서 한강공원특화사업에 대한 평가를 실시하였다. 특히 4권역 중 가장 높은 이용률의 여의도 권역과 가장 낮은 이용률의 반포 권역을 대상으로 비교, 평가하여 그 이유를 밝히고자 하였다. 이론고찰과 대상지 분석결과 이용의 높고 낮음은 프로그램의 차이에 있는 것으로 판단되었으며, 이에 프로그램의 관점에서 권역별 차별화된 프로그램, 중복된 프로그램, 사업에 부재한 프로그램으로 구분하여 두 권역을 평가하였다.  평가는 첫 번째, 이용자들이 생각하는 두 권역의 프로그램에 대한 중요도를 비교하여 프로그램 계획에 대한 이용후 평가를 실시한 후, 두 번째, 중요도와 만족도의 관계를 나타내는 IPA 분석을 통해 권역별 프로그램 성취도 평가 및 개선우선요소를 도출하는 것이다. 프로그램 이용후 평가 결과, 전반적으로 중요도에 비해 만족도가 낮아 이용의 관점에서 계획이 제대로 이루어지지 않은 것으로 나왔다. 특히 중요도가 높은 수질관련 문제와 프로그램 운영에 관한 부분은 계획내용에 없는 것으로 분석되었다. 또한 IPA 분석 결과, ‘수질정화시설’ 및 ‘운영프로그램의 지속성’에 대해서는 두 권역 모두 집중개선요소로 도출되었다. 여의도 권역은 성취도가 대체로 높으나 워터프론트 공원의 필수요소인 친수성, 안전성에 있어서 중점개선이 필요한 것으로 나타났으며, 반포 권역은 시설의 디자인, 심미성에 과잉 투자된 반면 운영이 제대로 이루어지고 있지 않아 성취도가 낮게 평가되었다. 다시 말해 한강공원특화사업 프로그램 계획을 이용자들을 대상으로 평가한 결과, 여의도 권역은 워터프론트 공원의 본질적인 면을 고려한 계획이 부족하며 반포 권역은 이용성보다 시각적인 요소에 치중한 계획이 이루어 진 것을 알 수 있다. 이는 두 권역 모두 한강을 시민에게 돌려주겠다는 초기 사업의 목적에 제대로 부합하고 있지 않은 것을 의미한다. 본 연구는 한강공원특화사업 대상권역에서 이용률의 낮고 높음은 프로그램과 관계된 것임을 밝히는 데에 의의를 두고 있다. 그러나 대상지가 두 권역에 한정되어 있으며 대상지 특성에 따라 다양한 특화 프로그램이 나올 수 있으므로 보편타당한 자료가 되기 힘들다는 데에 한계가 있다. 향후 다양한 권역에서 한강공원특화사업이 진행될 것으로 예상되며, 한강이 다시 시민의 일상의 장소로 돌아가기 위해 지속적인 프로그램 연구가 필요할 것이다.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
#        If the conditions stated above for establishing the marina in Han River area are observed, the marina will go beyond developing another waterfront facility and present the virtuous cycle of profit generation and re-investment in the public facilities. It'll also serve as a city amenity providing environment-friendly water sports and leisure activities, not just becoming another physical facilities. It is expected that the marina will play an important role of witnessing a proper, carefully thought maritime development can satisfy the people's needs for water sports and leisure activities, boost the economy in the area, and eventually improve people's quality of life significantly.rotection and harmony with the surroundings.  of Land, Transport and Maritime Affairs of Korea is endeavoring to facilitate the maritime leisure and sports by establishing and implementing visionary policies and plans to promote the industries including yacht related ones.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 7   漢江流域 新羅古墳 硏究 : 서울·경기지역을 중심으로  김진영 단국대학교 2007 국내석사  RANK : 27772927    원문보기 음성듣기             본고는 산재한 한강유역의 신라고분을 정리?분석하여 계보를 파악하고, 이에 따른 신라의 한강유역 진출경로를 설정해 보았다. 또한 고분군의 축조주체를 규명하여 신점령지에 대한 지배방식의 일면을 살펴보았으며 고분군의 분포와 구조적 변화에 근거하여 고분의 전개과정을 살펴보았다 그 결과 한강유역 신라고분은 크게 횡혈식석실묘, 횡구식석실묘, 수혈식석곽묘로 대별되며, 광주산맥을 경계로 한강본류 지역과 남한강유역 석실 간 계보을 달리한다. 한강본류지역 석실은 백제의 재지적속성과 합천과 창녕지역을 중심으로 한 영남서남부지역 석실에서 그 계보를 구할 수 있으며, 반면 여주지역을 중심으로 하는 남한강유역 석실은 상주, 문경, 영주, 안동, 예천 등 영남북부지역과 일부 고구려와 왕경인 경주지역 석실의 요소가 엿보여 대조적이다. 이에 전자를 한강본류계 석실, 후자를 남한강계 석실로 규정짓고 신라의 한강유역 진출경로를 추적해보았다. 한강본류계 석실은 그 기점을 김천지역에서 구할 수 있으며, 그 진출경로는 김천→추풍령→청원?청주→진천→안성→용인으로 이어지는 내륙로가 설정이 된다. 반면 남한강계 석실은 그 기점을 상주와 영주지역으로 구할 수 있으며 그 진출경로는 상주→문경→ 계립령→ 충주→여주로 이어지는 경로와 영주→죽령→충주→여주로 이어지는 남한강 수계를 따른 하천변로가 설정되어 신라의 한강유역 진출에 있어 단선적 경로가 아닌 양선적 경로가 이용되었음을 알 수 있었다. 고분군의 축조세력은 한강본류지역은 가야계 유민과 신라에 흡수된 재지층, 남한강유역은 왕경의 귀족층과 가야계 유민으로 이들은 어느 정도 독자적인 세력을 유지한 것으로 보인다. 그러나 신라의 삼국통일 이후 중앙집권적 국가체제로 전환되면서 이들의 통치세력은 크게 약화되어 중앙의 지배구조에 편입된다. 이러한 현상은 대단위고분군에서 소단위고분군으로 변화, 묘제의 통일성과 규격화 등 고분군에서도 여실히 나타난다. 마지막으로 묘형에 따른 속성분석에서 관찰된 변화양상을 통하여 한강유역 신라고분의 전개과정을 살펴보았는데 고분군의 분포와 구조적 변화에 따라 크게 4단계의 변화과정이 설정되었다. 1단계는 신라의 한강유역 진출기로 군사?정치적 요지에 한정하여 중?대형 고분군이 형성된다. 침향은 동향과 북향을 이룬다. 2단계는 안성천 내륙 및 임진강유역까지 영역의 확대가 이루어지나 군사적인 진출에 그친다. 고분군의 확산은 이루지지 않으며 추장이 이루어지는 단계로 석실의 조영이 감소한다. 침향은 동향이 사라진 북향으로 변화한다. 3단계는 신라가 삼국을 통일하고 羅唐戰爭을 거치면서 중앙집권적 체제로의 전환이 이루어지는 시기이다. 이에 중앙의 귀족과 유력한 지방의 통치세력은 중앙의 제도권에 완전 편입된다. 이에 고분도 주묘제가 석실에서 석곽으로, 교체되며 크기 및 유물부장 등 규격화 현상이 나타난다. 고분군은 대단위고분군은 형성되지 않으며 소단위고분군을 중심으로 광범위하게 확산된다. 4단계는 신라가 내적으로 갈등을 겪는 시기로 고분군은 구조상 간략화 되면서 고려 석곽묘로의 전환이 이루진다. The purpose of this study was to identify the lineage of Shilla tombs dispersed around Han River and the route of Shilla’s exploitation. Additionally, we investigated the aspects of their governing on the newly acquired land by identifying the subject of the construction of the tombs, and investigated the development of tombs based on the distribution and structural changes in tomb blocks. Consequently, the tombs could be classified as horizontal digging stone chamber to, horizontal entrance outer stone coffin tomb, and vertical digging outer stone coffin tomb. There are different lineages in mainstream area and southern bank area with the boundary of Gwangju Mountains. Mainstream stone chambers reflect the geographical characteristics of Baikje and share the same lineage with the stone chambers in southwest part of Youngnam including Habcheon and Changnyeong. On the other hand, the stone chambers in southern part of Han River show some characteristics northern part of Youngnam including Sangju, Mungyeong, Youngju, Andong and Yecheon, and a part of Goguryeo and Gyeongju, which is the royal capital. Therefore, we call the former Mainstream Stone Chambers and the latter Namhangang (Southern part of Han River) Stone Chambers and tracked the route of their exploit on Han River area. The origin of the mainstream chambers can be found in Gimcheon area and the route would be the in-land connecting Gimcheon→ Chupungryeong→Cheongwon and Cheongju→Jincheon→Anseong→ Yongin. On the other hand, Namhangang Stone Chambers can be found in Sangju and Youngju area and their routes would be stream shores following the Namhangang water system such as Sangju→Mungyeong→Gyeripgyreong→Chungju→Yeoju and Youngju→Jungryeong→Chungju→Yeoju. It shows the route of exploitation of Shilla was not a single line but dual lines. The subjects of tomb construction were the migrants from Gaya and natives absorbed to Shilla in case of Mainstream area and the nobles and the migrants from Gaya in case of Namhangang area. It seems that they had independent power to some extent. However, after Shilla succeeded in the reunification and established strong central government, their power became weak. Finally, we investigated the development of Shilla tombs near Han River through the changes observed from the attribute analysis according to the shapes of the tombs. There were 4 stages in the changes according to the distribution  ...
#
#
# 원문보기
#
#
# 음성듣기
#
#
# 8   한강수질오염에 관한 연구  곽호 단국대학교 1992 국내석사  RANK : 27772927    원문보기             우리나라는 1960년대 초부터 시작된 경제개발 정책으로 급속한 산업발전과 더불어 발생된 수도 서울의 집중화 현상은 한강의 수질 오염을 촉진시켜왔다. 이에따라 수질오염은 시급한문제가 되었다. 이러한 현상이 쾌적한 생활환경을 위협하는 것은 물론 인간생활을 근본적으로 위협하는 결과를 가져올 것이라고 예측하기란 그리 어려운 일이 아니다. 이에따라 여러 가지 한강의 수질오염방지대책이 강구되고 있는 현실에서 본 논문은 수질오염의 결과로 일어나는 제반 피해 상황과 근원적이고 사전 예방적인 대책을 세우기 위한 조치를 목적으로 연구를 시도해 본것이다. 연구의 범위와 방법으로는 각종 문헌과 연구사적 및 논문, 그리고 정부간행물을 참고하여 한강의 수질오염실태를 년도별로 살펴보고 수질을 오염시키는 오염물질을 파악해 보았으며, 외국의 수질관리를 살펴보았다. 본 논문을 쓰면서 수질오염을 분석한 결과 한강의 수질은 점점더 상류쪽으로 악화되어가고 있으며 산업발전으로 인한 이와같은 현상은 당분간 계속되리라는 결론을 얻었다. 앞으로 이와같은 수질오염의 확산을 방지하기 위해서는 정부의 과감한 투자와 강력한 정책이 이루어져야 할 것이며 온 국민의 수질개선을 위한 노력이 있어야 할 것이다. 제1장 서론에 이어 본 논문의 제2장에서는 수질오염의 의의와 수질오염이 주는 피해를 검토하였다. 제3장에는 한강의 수질오염실태를 년도별로 살펴보고 수질을 오염시키는 오염원과 오염물질을 파악해 보았으며 외국의 수질관리를 살펴보았다. 제4장에서는 한강의 수질오염을 처리할 수 있는 대책으로 수질오염의 근본적인 원인제거에 다각적이고 종합적인 대책이 추진되어야함을 강조하였고 제5장에서는 환경에 대한 투자를 제도적으로 확대시켜 경제개발 계획의 시행으로 오염이 심화된 한강수질오염의 방지사업을 종합적이고 체계적으로 운영해야 할 것을 제시하였다. The phenomenon of the centralization of population in the capital city, Seoul, occurred along with the rapid industrial development accelerated by the Economical Development Policy started from early 1960s has speeded up the water pollution of the Han river, resulting in an urgent problem to be settled. It is not that difficult to predict that such a phenomenon not only threatens people who want to live in safe and comfortable living environment but also will bring a result basically threatening human life. Accordingly, in the reality that any countermeasure to prevent the Han river from being polluted seriously is demanded, it has been attempted through the present thesis to study on the management to establish some preliminary, preventive plans to cope with all the damage that will happen in a result of serious water pollution. Following Chapter 1, Introduction, in Chapter 2, the significance and damage of water pollution are reviwed. In Chapter 3, the realities of the water pollution of the Han river are reviewed by each year respectively, and the pollutional sources and pollutants of water are understood with reference to the water control of some foreign countries. In Chapter 4, as for a countermeasure to cope with the water pollution of the Han river, it is emphasized that the original, basical exclusion of the causes of water pollution should be propelled multilaterally and sythetically. In Chapter 5, it is suggested that investment to creating good environment should be extended in terms of a system, so that the a preventive project to cope with an urgent problem of the water pollution of the Han river which has been seriously hightened by the enforcement of the Economical Development Plan should be synthetically and stystematically operated.
#
#
# 원문보기
#
#
#  주제어: 에코페미니즘, 한강, 톄닝, 여성문학, 페미니즘, 생태학모두 가부장적 위계질서와 이원론적 사고로 인해 야기된 갖가지 문제를 인식하고 있다. 가부장제의 지배에 대한 저항이라는 측면에서 두 작가 모두 가부장제에 저항하는 여성의 모습을 그려낸다. 하지만 한강에 비해 톄닝의 소설 속 여성의식의 발생은 과정성이 없이 줄곧 같은 방향으로 나아간다. 또한, 두 작가는 저항을 표현하는 방식도 다르게 표현한다. 한강의 여주인공은 내부로 부터 외부로 저항하는 과정에서 점차 자기 정체성을 깨닫게 된다. 톄닝의 여주인공은 사상적으로 전통적인 사상을 유지하고 있지만, 그녀의 행동은 이미 봉건적 전통의 굴레를 넘어 그녀 특유의 여성성을 아낌없이 드러낸다. 남성과 여성은 상호 보완적이라는 점에서 표현 형태가 크게 다르다. 한강은 남녀 공통의 '식물 체험'을 통해 여성성의 원리를 회복하고, 남녀가 조화롭게 공존할 수 있는 새로운 패러다임을 제시한다. 한강에 비해 톄닝은 소설에서 남녀가 어떻게 조화롭게 공존해야 하는지에 대한 답을 제시하지 않고, 대신 남성 '타자'의 정체성을 빌려 가부장적 위계를 남성의 관점에서 바라보며 남성성을 조명한다. 작품에 나타난 에코페미니즘적인 관점을 통해 환경문제와 여성문제 해결에 대한 시사점을 제시한다.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
#  결과적으로 설계 대상지인 반포둔치 외의 유사한 조건을 가진 수많은 둔치 및 섬에도 본 논문의 설계방안과 동일한 개념의 생태둔치 및 생태호안 설계가 가능하다. 한강 전역의 둔치 및 호안이 자연에 의한 천이가 일어날 수 있는 환경으로 바뀐다면 경관생태학적 스케일에서 볼 때 각각의 생태구역들이 징검다리 서식처 역할을 할 수 있으며, 한강은 이동통로로 기능할 수 있다. 수 있게 하였다. 않더라도 수위가 시시각각 변동한다. 예로 대조 때 잠수교 부근의 한강 수위는 하루에도 1.7m까지 오르락내리락 하며, 신곡 수중보에 의해 일정높이 이하로는 수위가 내려가지 않고, 잠실 수중보 상류는 서해 조석의 영향을 받지 않는다. 또한 여름 장마철에는 집중호우에 의해 한강물이 비약적으로 상승하여 대부분의 둔치가 범람된다. 이러한 수위변동은 그동안 인간에게 위협적인 요소로 인식되어왔고, 다양한 수방시설과 수방대책이 수립되었다. 그러나 생태적 측면에서는 주기적인 범람이 오히려 많은 장점을 가지고 있기 때문에, 이 점을 잘 활용하면 한강의 생태계를 풍부하게 할 수 있을 뿐 아니라 시민들도 한강에서 생태적으로 훨씬 다양한 경험을 할 수 있는 공원을 조성할 수 있다. 조성되지 못하였다.
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
# 수집된 결과는 한강 에 저장되었습니다

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

print("=" *100)
print("네이버 뉴스 기사 내용 추출")
print("=" *100)

query_txt = input('입력할 검색어: ')
print("\n")

s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://naver.com'
driver.get(url)
time.sleep(5)
driver.maximize_window()

element = driver.find_element(By.ID, 'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")

driver.find_element(By.LINK_TEXT,'뉴스').click()
time.sleep(2)

from bs4 import BeautifulSoup
html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

soup_1.find('div', 'group_news').find_all('li')
# Out:
# ====================================================================================================
# 네이버 뉴스 기사 내용 추출
# ====================================================================================================
